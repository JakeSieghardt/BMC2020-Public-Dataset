# %% [markdown]
# # Ordinal Encodings
#
# In this notebook, we share the final values for the representation of ordinal values using fuzzy sets obtained using the methods described in our paper _"Ordinal labels in machine learning: a user-centered approach to improve data validity in medical settings"_.
#
# In particular, we share:
#
# - CoIED and RP medians computed on both doctors and patients datasets,
# - Membership vector encodings,
# - Weighted sampling encodings.
#
# For the weighted sampling encodings, a specific random seed (42) was used. In that case, results change depending on randomness.
#
# The datasets discussed in the article are shared in this repository, under the folder "data".

# %%
#############

coied_doctors = {
    'Absent': 9.2,
    'Mild': 25.9,
    'Moderate': 46.7,
    'Severe': 67.5,
    'Extreme': 88.0
}

#############

rp_median_doctors = {
    'Absent': 6.0,
    'Mild': 22.5,
    'Moderate': 47.0,
    'Severe': 70.0,
    'Extreme': 91.5
}

#############

coied_patients = {
    'Absent': 13.79,
    'Mild': 26.53,
    'Moderate': 41.28,
    'Severe': 57.99,
    'Extreme': 70.81
}

#############

rp_mean_patients = {
    'Absent': 0.0,
    'Mild': 20.0,
    'Moderate': 50.0,
    'Severe': 75.0,
    'Extreme': 100.0
}

##############

membership = {
    'Absent': {0.0: 0.89, 1.0: 0.08, 2.0: 0.02, 3.0: 0.01, 4.0: 0.0},
    'Mild': {0.0: 0.0, 1.0: 1.0, 2.0: 0.0, 3.0: 0.0, 4.0: 0.0},
    'Moderate': {0.0: 0.0, 1.0: 0.05, 2.0: 0.95, 3.0: 0.0, 4.0: 0.0},
    'Severe': {0.0: 0.0, 1.0: 0.0, 2.0: 0.11, 3.0: 0.89, 4.0: 0.0},
    'Extreme': {0.0: 0.0, 1.0: 0.0, 2.0: 0.0, 3.0: 0.01, 4.0: 0.99}
}

##############

weighted_sampling = {
    'Absent': 14.0, 
    'Mild': 23.0, 
    'Moderate': 43.0, 
    'Severe': 80.0,
    'Extreme': 90.0
}
